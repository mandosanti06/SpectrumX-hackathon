# %% [markdown]
# <a href="https://colab.research.google.com/github/mandosanti06/SpectrumX-hackathon/blob/main/traceAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Spectrum Trace Analysis
#
# Answer the following questions about the provided trace.
#
# 1. Plot the spectrogram and the MAX frequency hold of the trace.
# 2. What kind of a signal is this (what does the signal look like)?
# 3. How many bursts are there? What is the duration of each burst? Take the number of rows in the burst and multiply by the row duration.
# 4. How big is the gap between each burst? Take the number of rows in the gap and multiply by the row duration.
# 5. What is the power level of the transmitter?
# 6. What is the mean noise value?
# 7. What is the mean transmitter value?
#
# You can use the code below to help get started.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas

filename = '98MHz.csv' #change the filename
center_frequency = 0
fft_size = 1024
sample_rate = 1e6
spectrogram = pandas.read_csv(filename, header=None)
spectrogram = spectrogram.to_numpy()
print(spectrogram)
plt.imshow(spectrogram, cmap=plt.cm.spring, aspect='auto')
plt.title("Spectrogram")
plt.xlabel("Frequency Bins")
plt.ylabel("Time [ms]")
plt.show()
# Out:
# [[-111.527  -111.823  -126.083  ... -119.763  -106.149   -99.8269]
#  [-119.099  -104.324  -103.553  ... -106.09   -107.056  -106.13  ]
#  [-102.943  -104.373  -104.947  ... -106.779  -105.294  -106.564 ]
#  ...
#  [-104.855  -105.611  -107.638  ... -109.117  -111.307  -115.005 ]
#  [-105.786  -104.929  -102.773  ... -101.133  -102.409  -105.81  ]
#  [-105.033  -103.18   -103.89   ... -105.05   -104.231  -104.315 ]]
